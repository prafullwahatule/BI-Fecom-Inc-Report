# %% [markdown]
# <a href="https://colab.research.google.com/github/harshada4912/Data_analysis/blob/main/Python1(Operator).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Write a Python program to take two numbers as input from the user and display their sum.

# %%
a = int(input("Enter a first number="))
b = int(input("Enter a second number="))
sum = a+b
print("addition of two numbers=", sum)
# Out:
# Enter a first number=10
# Enter a second number=15
# addition of two numbers= 25

# %% [markdown]
# 2. Calculate and print the midpoint of two numbers entered by the user.

# %%
a = int(input("Enter a first number="))
b = int(input("Enter a second number="))
midpoint = (a+b)/2
print("midpoint of two numbers=" , midpoint)
# Out:
# Enter a first number=12
# Enter a second number=52
# midpoint of two numbers= 32.0

# %% [markdown]
# 3.Write a Python program to calculate the area of a triangle using the formula: area = 0.5 * base * height.

# %%
base = int(input("enter a base number="))
height = int(input("enter a base number="))
area = 0.5*base*height
print("area of triangle=", area)
# Out:
# enter a base number=10
# enter a base number=25
# area of triangle= 125.0

# %% [markdown]
# 4.	Take three numbers as input from the user and display their product.

# %%
base = float(input("Enter base: "))
height = float(input("Enter height: "))
area = 0.5 * base * height
print("Area of triangle =", area)
# Out:
# Enter base: 16
# Enter height: 29
# Area of triangle = 232.0

# %% [markdown]
# 5. Take a number as input and display its square and cube.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
print("Product =", a * b * c)
# Out:
# Enter first number: 13
# Enter second number: 39
# Enter third number: 45
# Product = 22815

# %% [markdown]
# 6. Take two numbers as input and display their quotient and remainder.

# %%
num = float(input("Enter a number: "))
print("Square =", num ** 2)
print("Cube =", num ** 3)
# Out:
# Enter a number: 2
# Square = 4.0
# Cube = 8.0

# %% [markdown]
# 7. Take three numbers as input and display their average.

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))
avg = (a + b + c) / 3
print("Average =", avg)
# Out:
# Enter first number: 14
# Enter second number: 20
# Enter third number: 35
# Average = 23.0

# %% [markdown]
# 8. Write a Python program to calculate the area of a rectangle using the formula: area = length * width.

# %%
length = float(input("Enter length: "))
width = float(input("Enter width: "))
area = length * width
print("Area of rectangle =", area)
# Out:
# Enter length: 3
# Enter width: 5
# Area of rectangle = 15.0

# %% [markdown]
# 9. Take five numbers as input representing marks obtained and total marks.

# %%
Maths = int(input("enter a maths number="))
Science = int(input("enter a science number="))
Marathi = int(input("enter a marathi number="))
Hindi = int(input("enter a hindi number="))
Evs = int(input("enter a Evs number="))

print("percentage of five numbers=", ((Maths+Science+Marathi+Hindi+Evs)/500)*100)
# Out:
# enter a maths number=50
# enter a science number=46
# enter a marathi number=50
# enter a hindi number=60
# enter a Evs number=50
# percentage of five numbers= 51.2

# %% [markdown]
# 10. Write a Python program to swap two numbers entered by the user without using a third variable.

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
a, b = b, a
print("After swapping: a =", a, ", b =", b)
# Out:
# Enter first number: 12
# Enter second number: 28
# After swapping: a = 28.0 , b = 12.0

# %% [markdown]
# 11. Take a number as input and check whether it is even or odd.

# %%
Num = int(input("enter a number="))

if Num % 2 == 0:
  print("even number")
else:
  print("odd number")
# Out:
# enter a number=15
# odd number

# %% [markdown]
# 12. Write a Python program to convert temperature from Celsius to Fahrenheit using the formula: F = (C × 9/5) + 32

# %%
c = int(input("Enter temperature in Celsius: "))
f = (c * 9/5) + 32
print("Temperature in Fahrenheit =", f)
# Out:
# Enter temperature in Celsius: 23
# Temperature in Fahrenheit = 73.4

# %% [markdown]
# 13. Write a Python program to convert temperature from Fahrenheit to Celsius using the formula: C = (F - 32) × 5/9.

# %%
F = int(input("enter tempreture in celsius="))
C = (F -32)* 5/9
print("convert tempreture from fahrenheit to celsius=", C )
# Out:
# enter tempreture in celsius=12
# convert tempreture from fahrenheit to celsius= -11.11111111111111
